# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from yellowbrick.cluster import KElbowVisualizer

# %%
df = pd.read_csv("PCA_Customer_Data.csv")
df = df.drop('Unnamed: 0', axis=1)
df.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6
# 0 -0.230403 -0.012272  0.233339 -0.119963 -0.082365 -0.378263
# 1  0.372348  0.014527 -0.380164 -0.074397 -0.002281 -0.150753
# 2  0.437912  0.003296 -0.087938 -0.034842  0.038757 -0.078460
# 3  0.457492  0.004329 -0.081497 -0.018593  0.038919 -0.085442
# 4  0.228929 -0.027076  0.648573  0.066576  0.130170  0.150845

# %%
df.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6
# 0 -0.230403 -0.012272  0.233339 -0.119963 -0.082365 -0.378263
# 1  0.372348  0.014527 -0.380164 -0.074397 -0.002281 -0.150753
# 2  0.437912  0.003296 -0.087938 -0.034842  0.038757 -0.078460
# 3  0.457492  0.004329 -0.081497 -0.018593  0.038919 -0.085442
# 4  0.228929 -0.027076  0.648573  0.066576  0.130170  0.150845

# %%
#Data Distribution

sns.pairplot(df)
plt.show()

# %%
scaled_df = StandardScaler().fit_transform(df) #scaling the dataframe

# %% [markdown]
# ## Elbow Method

# %%
#kmeans parameters
kmeans_kwargs = {
"init": "random",
"n_init": 10,
"random_state": 1,
}


sse = [] #sum of squared error list
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(scaled_df)
    sse.append(kmeans.inertia_)

plt.plot(range(2, 11), sse)
plt.xticks(range(2, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()
# Out:
# C:\Users\anish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\anish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\anish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\anish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\anish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\anish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\anish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\anish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\anish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# #### It is observed that there is a strong bend at 7.

# %% [markdown]
# ### Alternate Library for elbow method

# %%
model = KMeans()
visualizer = KElbowVisualizer(
    model, k=(1,1), metric='calinski_harabasz', timings=False
)
visualizer.fit(scaled_df)        # Fit the data to the visualizer
visualizer.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       1 model = KMeans()
#       2 visualizer = KElbowVisualizer(
#       3     model, k=(1,1), metric='calinski_harabasz', timings=False
#       4 )
# ----> 5 visualizer.fit(df)        # Fit the data to the visualizer
#       6 visualizer.show()
#
# File ~\anaconda3\Lib\site-packages\yellowbrick\cluster\elbow.py:364, in KElbowVisualizer.fit(self, X, y, **kwargs)
#     349 if self.locate_elbow:
#     350     locator_kwargs = {
#     351         "distortion": {
#     352             "curve_nature": "convex",
#    (...)
#     362         },
#     363     }.get(self.metric, {})
# --> 364     elbow_locator = KneeLocator(
#     365         self.k_values_, self.k_scores_, **locator_kwargs
#     366     )
#     367     if elbow_locator.knee is None:
#     368         self.elbow_value_ = None
#
# File ~\anaconda3\Lib\site-packages\yellowbrick\utils\kneed.py:110, in KneeLocator.__init__(self, x, y, S, curve_nature, curve_direction, online)
#     107 self.online = online
#     109 # Step 1: fit a smooth line
# --> 110 uspline = interpolate.interp1d(self.x, self.y)
#     111 self.Ds_y = uspline(self.x)
#     113 # Step 2: normalize values
#
# File ~\anaconda3\Lib\site-packages\scipy\interpolate\_interpolate.py:543, in interp1d.__init__(self, x, y, kind, axis, copy, bounds_error, fill_value, assume_sorted)
#     541 # Interpolation goes internally along the first axis
#     542 self.y = y
# --> 543 self._y = self._reshape_yi(self.y)
#     544 self.x = x
#     545 del y, x  # clean up namespace to prevent misuse; use attributes
#
# File ~\anaconda3\Lib\site-packages\scipy\interpolate\_polyint.py:113, in _Interpolator1D._reshape_yi(self, yi, check)
#     110     ok_shape = "{!r} + (N,) + {!r}".format(self._y_extra_shape[-self._y_axis:],
#     111                                            self._y_extra_shape[:-self._y_axis])
#     112     raise ValueError("Data must be of shape %s" % ok_shape)
# --> 113 return yi.reshape((yi.shape[0], -1))
#
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)

# %%
#instantiate the k-means class, using optimal number of clusters
kmeans = KMeans(init="random", n_clusters=7, n_init=10, random_state=1)
kmeans.fit(scaled_df)
# Out:
# C:\Users\anish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(init='random', n_clusters=7, n_init=10, random_state=1)
